# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df  = pd.read_csv('C:/Users/Ola/Desktop/filess/NFLX.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  05/02/2018  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  06/02/2018  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  07/02/2018  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  08/02/2018  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  09/02/2018  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
df.shape
# Out:
# (1009, 7)

# %%
df.Date.unique()
# Out:
# array(['05/02/2018', '06/02/2018', '07/02/2018', ..., '02/02/2022',
#        '03/02/2022', '04/02/2022'], dtype=object)

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.drop('Date', axis=1, inplace=True)
df.head(11)
# Out:
#           Open        High         Low       Close   Adj Close    Volume
# 0   262.000000  267.899994  250.029999  254.259995  254.259995  11896100
# 1   247.699997  266.700012  245.000000  265.720001  265.720001  12595800
# 2   266.579987  272.450012  264.329987  264.559998  264.559998   8981500
# 3   267.079987  267.619995  250.000000  250.100006  250.100006   9306700
# 4   253.850006  255.800003  236.110001  249.470001  249.470001  16906900
# 5   252.139999  259.149994  249.000000  257.950012  257.950012   8534900
# 6   257.290009  261.410004  254.699997  258.269989  258.269989   6855200
# 7   260.470001  269.880005  260.329987  266.000000  266.000000  10972000
# 8   270.029999  280.500000  267.630005  280.269989  280.269989  10759700
# 9   278.730011  281.959991  275.690002  278.519989  278.519989   8312400
# 10  277.739990  285.809998  276.609985  278.549988  278.549988   7769000

# %%
o= (df.Open.max())
o
# Out:
# 692.349976

# %%
x = (df[['Open', 'High', 'Low', 'Close', 'Adj Close']])
x
# Out:
#             Open        High         Low       Close   Adj Close
# 0     262.000000  267.899994  250.029999  254.259995  254.259995
# 1     247.699997  266.700012  245.000000  265.720001  265.720001
# 2     266.579987  272.450012  264.329987  264.559998  264.559998
# 3     267.079987  267.619995  250.000000  250.100006  250.100006
# 4     253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...
# 1004  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  407.309998  412.769989  396.640015  410.170013  410.170013
#
# [1009 rows x 5 columns]

# %%
x["Adj_Close"] = x["Adj Close"]
x.drop('Adj Close', axis=1)
# Out:
#             Open        High         Low       Close   Adj_Close
# 0     262.000000  267.899994  250.029999  254.259995  254.259995
# 1     247.699997  266.700012  245.000000  265.720001  265.720001
# 2     266.579987  272.450012  264.329987  264.559998  264.559998
# 3     267.079987  267.619995  250.000000  250.100006  250.100006
# 4     253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...
# 1004  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  407.309998  412.769989  396.640015  410.170013  410.170013
#
# [1009 rows x 5 columns]

# %%
y = df.Volume
y.head()
# Out:
# 0    11896100
# 1    12595800
# 2     8981500
# 3     9306700
# 4    16906900
# Name: Volume, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,random_state=40)

# %%
from sklearn.naive_bayes import GaussianNB
le  = GaussianNB()
le.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
le.score(X_test,y_test)
# Out:
# 0.0

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import HuberRegressor

# %%
model = Pipeline([('Rand', RandomForestRegressor())])
model2 = Pipeline([('linear', LinearRegression())])
model3 = Pipeline([('svm', SVC(C=10, kernel='linear'))])
model4 = Pipeline([('tree', DecisionTreeClassifier())])
model5 = Pipeline([('berli', LogisticRegression())])
model6 = Pipeline([('Lasso', Lasso())])
model7 = Pipeline([('Ridge', Ridge())])
model8 = Pipeline([('huber', HuberRegressor())])

# %%
def model_accuracy():
    scores=[]
    
    score1 = model.fit(X_train,y_train)
    scores.append(score1.score(X_test, y_test)),
    
    score2 = model2.fit(X_train,y_train)
    scores.append(score2.score(X_test, y_test)),
    
    score3 = model3.fit(X_train,y_train)
    scores.append(score3.score(X_test, y_test))
    
    score4 = model4.fit(X_train,y_train)
    scores.append(score4.score(X_test, y_test))
    
    score5 = model5.fit(X_train,y_train)
    scores.append(score5.score(X_test, y_test))
    
    score6 = model6.fit(X_train,y_train)
    scores.append(score6.score(X_test, y_test))
    
    score7 = model7.fit(X_train,y_train)
    scores.append(score7.score(X_test, y_test))
    
    score8 = model8.fit(X_train,y_train)
    scores.append(score8.score(X_test, y_test))
    
    return scores

# %%
model_accuracy()
# Out:
# C:\Users\Ola\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Ola\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.659e+15, tolerance: 2.118e+12
#   model = cd_fast.enet_coordinate_descent(
# [0.27924035207069464,
#  0.37731425687463493,
#  0.0,
#  0.0,
#  0.0,
#  0.4134120211770539,
#  0.37731841641974595,
# ...

# %% [markdown]
# **Linear model models happens to be the best with Lasso emerging with the highest accuracy acore.**

# %%
import numpy as np
def get_Volume(Open,High,Low,Close,Adj_Close):
    columns = np.zeros(len(x.columns))
    columns[0] = (Open)
    columns[1] = (High)
    columns[2] = (Low)
    columns[3] = (Close)
    columns[4] = (Adj_Close)
    
    return model6.predict([columns])[0]

# %%
get_Volume(234,423,284,592,254)
# Out:
# C:\Users\Ola\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# 85445923.63242275

# %%
get_Volume(262,267,250,254,254)
# Out:
# C:\Users\Ola\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# 13480448.057638742

# %%
from sklearn.metrics import classification_report
y_pred = model4.predict(X_test)
report=classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      1367800       0.00      0.00      0.00       0.0
#      1595500       0.00      0.00      0.00       0.0
#      1621100       0.00      0.00      0.00       0.0
#      1673900       0.00      0.00      0.00       0.0
#      1736000       0.00      0.00      0.00       0.0
#      1780700       0.00      0.00      0.00       0.0
#      1867300       0.00      0.00      0.00       0.0
#      1882800       0.00      0.00      0.00       1.0
#      1906600       0.00      0.00      0.00       1.0
#      1995900       0.00      0.00      0.00       0.0
#      2012900       0.00      0.00      0.00       1.0
#      2019300       0.00      0.00      0.00       0.0
#      2039400       0.00      0.00      0.00       0.0
#      2061500       0.00      0.00      0.00       1.0
#      2065600       0.00      0.00      0.00       1.0
#      2077400       0.00      0.00      0.00       1.0
# ...

# %%
get_Volume(262.000000,267.899994,250.029999,254.259995,254.25999)
# Out:
# C:\Users\Ola\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# 13761813.285919629

# %%
import pickle

# %%
pickle.dump(model6,open("NFLX_pickle_file.pickle", 'wb'))
